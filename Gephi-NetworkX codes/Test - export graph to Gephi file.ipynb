# %%
import networkx as nx
import math
import sys
import matplotlib.pyplot as plt

# %%
#g=nx.read_edgelist('OTCNet.txt', delimiter=',', create_using=nx.Graph(), nodetype=str )

# %%
#nx.draw(g)

# %%
#nx.info(g)

# %%
import pandas as pd
df = pd.read_csv('OTCNet.txt', sep=',')  #   , skiprows=1

# %%
print (df)
# Out:
#        From    To  Trust
# 0         6     2    0.4
# 1         6     5    0.2
# 2         1    15    0.1
# 3         4     3    0.7
# 4        13    16    0.8
# 5        13    10    0.8
# 6         7     5    0.1
# 7         2    21    0.5
# 8         2    20    0.5
# 9        21     2    0.5
# 10       21     1    0.8
# 11       21    10    0.8
# 12       21     8    0.9
# 13       21     3    0.7
# 14       17     3    0.5
# 15       17    23    0.1
# 16       10     1    0.8
# 17       10     6    0.7
# 18       10    21    0.8
# 19       10     8    0.1
# 20       10    25    1.0
# 21       10     2    0.7
# 22       10     3    0.7
# 23        4    26    0.1
# 24       26     4    0.1
# 25        5     1    0.3
# 26        5     6    0.3
# 27        5     7    0.1
# 28        1     5    0.4
# 29        6     4    0.2
# ...     ...   ...    ...
# 35562  5688  5318    0.1
# 35563  1639  2067    0.1
# 35564  2067  1639    0.1
# 35565  2067  2045    0.7
# 35566   481  1810    0.6
# ...

# %%
G2 = nx.DiGraph()

# %%
for idx, row in df.iterrows():
    G2.add_node(row['From'], to=row['To'], trust=row['Trust'])

# %%
trust1 = [ d['trust'] for n, d in G2.nodes(data=True)]

# %%
nx.draw_networkx(G2, node_color=trust1)

# %%
#fh11=open("OTCNet.txt", 'r')

# %%
G11=nx.read_weighted_edgelist("OTCNet.csv",delimiter=',', nodetype=int)

# %%
G11

# %%
pos = nx.spring_layout(G11)

# %%
# nodes
nx.draw_networkx_nodes(G11, pos, node_size=5)

# %%
elarge = [(u, v) for (u, v, d) in G11.edges(data=True) if d['weight'] > 0.5]
esmall = [(u, v) for (u, v, d) in G11.edges(data=True) if d['weight'] <= 0.5]

# %%
# edges
nx.draw_networkx_edges(G11, pos, edgelist=elarge,
                       width=6)
nx.draw_networkx_edges(G11, pos, edgelist=esmall,
                       width=6, alpha=0.5, edge_color='b', style='dashed')

# %%
# labels
nx.draw_networkx_labels(G11, pos, font_size=20, font_family='sans-serif')
# Out:
# {6: Text(-0.466909,0.271879,'6'),
#  2: Text(-0.254489,0.0313721,'2'),
#  5: Text(-0.306146,0.0667188,'5'),
#  1: Text(-0.190653,-0.109419,'1'),
#  15: Text(-0.223353,0.00942838,'15'),
#  4: Text(-0.454983,-0.453242,'4'),
#  3: Text(-0.50935,0.414301,'3'),
#  13: Text(-0.337224,0.054861,'13'),
#  16: Text(-0.359882,0.0571884,'16'),
#  10: Text(-0.297446,0.126508,'10'),
#  7: Text(-0.138612,0.010086,'7'),
#  21: Text(-0.61183,-0.208371,'21'),
#  20: Text(-0.16575,0.555485,'20'),
#  8: Text(-0.411999,-0.142077,'8'),
#  17: Text(-0.394647,0.51895,'17'),
#  23: Text(0.0371045,-0.211649,'23'),
#  25: Text(-0.0752487,0.533083,'25'),
#  26: Text(-0.542094,0.392392,'26'),
#  28: Text(-0.152786,0.0680853,'28'),
#  29: Text(-0.0692709,-0.180542,'29'),
#  31: Text(-0.310518,-0.265709,'31'),
#  32: Text(-0.098062,-0.073813,'32'),
#  34: Text(-0.240753,-0.01448,'34'),
#  35: Text(-0.0748871,-0.0370428,'35'),
#  36: Text(-0.0783978,-0.0906763,'36'),
#  37: Text(-0.0523739,-0.126788,'37'),
# ...

# %%
plt.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
plt.axis('on')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
plt.show()

# %%
# nodes
nx.draw_networkx_nodes(G11, pos, node_size=5)

# edges
nx.draw_networkx_edges(G11, pos, edgelist=elarge,
                       width=6)
nx.draw_networkx_edges(G11, pos, edgelist=esmall,
                       width=6, alpha=0.5, edge_color='b', style='dashed')

# %%
# nodes
nx.draw_networkx_nodes(G11, pos, node_size=5)

# edges
nx.draw_networkx_edges(G11, pos, edgelist=elarge,
                       width=6)
nx.draw_networkx_edges(G11, pos, edgelist=esmall,
                       width=6, alpha=0.5, edge_color='b', style='dashed')

# labels
nx.draw_networkx_labels(G11, pos, font_size=20, font_family='sans-serif')
# Out:
# {6: Text(-0.466909,0.271879,'6'),
#  2: Text(-0.254489,0.0313721,'2'),
#  5: Text(-0.306146,0.0667188,'5'),
#  1: Text(-0.190653,-0.109419,'1'),
#  15: Text(-0.223353,0.00942838,'15'),
#  4: Text(-0.454983,-0.453242,'4'),
#  3: Text(-0.50935,0.414301,'3'),
#  13: Text(-0.337224,0.054861,'13'),
#  16: Text(-0.359882,0.0571884,'16'),
#  10: Text(-0.297446,0.126508,'10'),
#  7: Text(-0.138612,0.010086,'7'),
#  21: Text(-0.61183,-0.208371,'21'),
#  20: Text(-0.16575,0.555485,'20'),
#  8: Text(-0.411999,-0.142077,'8'),
#  17: Text(-0.394647,0.51895,'17'),
#  23: Text(0.0371045,-0.211649,'23'),
#  25: Text(-0.0752487,0.533083,'25'),
#  26: Text(-0.542094,0.392392,'26'),
#  28: Text(-0.152786,0.0680853,'28'),
#  29: Text(-0.0692709,-0.180542,'29'),
#  31: Text(-0.310518,-0.265709,'31'),
#  32: Text(-0.098062,-0.073813,'32'),
#  34: Text(-0.240753,-0.01448,'34'),
#  35: Text(-0.0748871,-0.0370428,'35'),
#  36: Text(-0.0783978,-0.0906763,'36'),
#  37: Text(-0.0523739,-0.126788,'37'),
# ...

# %%
# nodes
nx.draw_networkx_nodes(G11, pos, node_size=5)

# edges
nx.draw_networkx_edges(G11, pos, edgelist=elarge,
                       width=6)
nx.draw_networkx_edges(G11, pos, edgelist=esmall,
                       width=6, alpha=0.5, edge_color='b', style='dashed')

# labels
nx.draw_networkx_labels(G11, pos, font_size=4, font_family='sans-serif')

plt.axis('off')
plt.show()

# %%
# nodes
nx.draw_networkx_nodes(G11, pos, node_size=5)

# edges
nx.draw_networkx_edges(G11, pos, edgelist=elarge,
                       width=6)
nx.draw_networkx_edges(G11, pos, edgelist=esmall,
                       width=6, alpha=0.5, edge_color='b', style='dashed')

# labels
nx.draw_networkx_labels(G11, pos, font_size=4, font_family='sans-serif')

plt.axis('off')
plt.show()

# %%
# nodes
nx.draw_networkx_nodes(G11, pos, node_size=1)

# edges
nx.draw_networkx_edges(G11, pos, edgelist=elarge,
                       width=2)
nx.draw_networkx_edges(G11, pos, edgelist=esmall,
                       width=2, alpha=0.1, edge_color='g', style='dashed')

# %%
# nodes
nx.draw_networkx_nodes(G11, pos, node_size=1)

# edges
nx.draw_networkx_edges(G11, pos, edgelist=elarge,
                       width=2)
nx.draw_networkx_edges(G11, pos, edgelist=esmall,
                       width=2, alpha=0.01, edge_color='g', style='dashed')
